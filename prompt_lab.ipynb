# %% [markdown]
# # Week 1 — The Prompt Lab
#
# Five experiments. Each one changes **one thing** about how you ask, so you can see what
# that one thing does.
#
# **How to work through this**
#
# 1. Run the cells in order, one at a time.
# 2. After each experiment, fill in the ✍️ notes cell underneath it. Write in sentences.
# 3. Do not skip the notes — they are what we use in the discussion at the end, and they
#    are the point of the session.
#
# **What to expect**
#
# - `429` means you hit the rate limit: about 6 requests per minute on the free tier. The
#   helper waits and retries. It is not a mistake, it is the free tier.
# - `503` means the model is busy for everyone. The helper backs off and retries.
# - A warning about "automatic function calling" appears on every call. Ignore it.

# %%
from prompt_lab import ask, repeat

# %% [markdown]
# ---
# ## Experiment 1 — vague, then specific
#
# Same topic. Same model. Run both and compare the length and the usefulness.

# %%
ask("Tell me about Lviv.", label="1a vague")
# Out:
# === 1a vague ====================================================
# > Tell me about Lviv.
#
# Here’s a concise overview of Lviv, Ukraine.
#
# What it is
# - A major historical city in western Ukraine, and the administrative center of Lviv Oblast.
# - Known for its rich cultural life, architecture, universities, and a distinctive Central European atmosphere.
#
# History and identity
# - Founded in the 13th century by the Galician princes; over the centuries it has been part of Poland, Austria-Hungary, and the Ukrainian SSR before becoming part of independent Ukraine.
# - A true crossroads of cultures: Ukrainian, Polish, Jewish, Armenian, and Lithuanian influences are visible in its streets and buildings.
#
# What to see and do
# - Historic Centre (a UNESCO World Heritage Site): cobbled streets, ornate churches, and grand square landmarks.
# - Lviv Opera House: one of Europe’s most beautiful opera houses, a top venue for performances.
# - Rynok Square (Market Square) and the neighboring Market Hall: lively, with coffee houses, souvenir stalls, and historic architecture.
# - Armenian Cathedral and Armenian Street: reminders of Lviv’s diverse past.
# - Latin Cathedral and Dominikan Church: striking examples of the city’s religious architecture.
# - Lviv University and the Pharmacy Museum: historic sites with a strong intellectual vibe.
# - Museums and galleries: Lviv Historical Museum, Lviv National Museum, and small contemporary art spaces.
# - Coffee culture: Lviv is famous for its coffee houses and a long tradition of café culture. It’s common to see coffee served with flair and even “coffee aroma” tours.
# - Parks and views: High Castle Hill (Vysokyi Zamok) offers a panoramic view of the city.
#
# Culture and events
# - A vibrant cultural calendar: Book Forum Lviv, one of Ukraine’s largest literary events, plus numerous music, theater, and film festivals year-round.
# - A strong café-and-pastry scene, with local favorites and modern fusion spots.
# - Traditional Ukrainian crafts, markets, and a lively bookstore scene.
#
# People and language
# - The city feels cosmopolitan with a deep sense of local pride. Ukrainian is the primary language, with Polish and Russian also heard, and English common in tourist and university contexts.
#
# Education and economy
# - Home to several universities and a strong educational sector.
# - The economy is historically diverse—education, IT, tourism, manufacturing, and creative industries.
#
# Travel tips
# - Getting there: Well-connected by rail and road to Kyiv and other Ukrainian cities; international flights operate via Kyiv and Lviv’s own airport (seasonal/limited).
# - Getting around: Compact center is walkable; taxis and rideshares are common. Public transit exists but many visitors stick to walking routes in the Old Town.
# - Safety: Western Ukraine has been affected by conflict in recent years, but Lviv City Center and major tourist areas have generally been safer than frontline regions. Check official travel advisories and local guidance before planning trips.
# - Currency and payments: Ukrainian hryvnia (UAH). Credit cards widely accepted in urban areas; carry some cash for smaller places.
# - Best time to visit: Spring and autumn for pleasant weather; winter for festive markets and a cozy atmosphere; summer for longer days and lively street life.
#
# If you’d like, I can tailor this to:
# - A quick 1–2 day Lviv itinerary
# - Specific interests (architecture, food, history, nightlife)
# - Practical travel info (current safety, transport options, or where to stay)
#
#   [tokens] prompt=12 thinking=192 answer=704
# 'Here’s a concise overview of Lviv, Ukraine.\n\nWhat it is\n- A major historical city in western Ukraine, and the administrative center of Lviv Oblast.\n- Known for its rich cultural life, architecture, universities, and a distinctive Central European atmosphere.\n\nHistory and identity\n- Founded in the 13th century by the Galician princes; over the centuries it has been part of Poland, Austria-Hungary, and the Ukrainian SSR before becoming part of independent Ukraine.\n- A true crossroads of cultures: Ukrainian, Polish, Jewish, Armenian, and Lithuanian influences are visible in its streets and buildings.\n\nWhat to see and do\n- Historic Centre (a UNESCO World Heritage Site): cobbled streets, ornate churches, and grand square landmarks.\n- Lviv Opera House: one of Europe’s most beautiful opera houses, a top venue for performances.\n- Rynok Square (Market Square) and the neighboring Market Hall: lively, with coffee houses, souvenir stalls, and historic architecture.\n- Armenian Cathedral and Armenian Street: reminders of Lviv’s diverse past.\n- Latin Cathedral and Dominikan Church: striking examples of the city’s religious architecture.\n- Lviv University and the Pharmacy Museum: historic sites with a strong intellectual vibe.\n- Museums and galleries: Lviv Historical Museum, Lviv National Museum, and small contemporary art spaces.\n- Coffee culture: Lviv is famous for its coffee houses and a long tradition of café culture. It’s common to see coffee served with flair and even “coffee aroma” tours.\n- Parks and views: High Castle Hill (Vysokyi Zamok) offers a panoramic view of the city.\n\nCulture and events\n- A vibrant cultural calendar: Book Forum Lviv, one of Ukraine’s largest literary events, plus numerous music, theater, and film festivals year-round.\n- A strong café-and-pastry scene, with local favorites and modern fusion spots.\n- Traditional Ukrainian crafts, markets, and a lively bookstore scene.\n\nPeople and language\n- The city feels cosmopolitan with a deep sense of local pride. Ukrainian is the primary language, with Polish and Russian also heard, and English common in tourist and university contexts.\n\nEducation and economy\n- Home to several universities and a strong educational sector.\n- The economy is historically diverse—education, IT, tourism, manufacturing, and creative industries.\n\nTravel tips\n- Getting there: Well-connected by rail and road to Kyiv and other Ukrainian cities; international flights operate via Kyiv and Lviv’s own airport (seasonal/limited). \n- Getting around: Compact center is walkable; taxis and rideshares are common. Public transit exists but many visitors stick to walking routes in the Old Town.\n- Safety: Western Ukraine has been affected by conflict in recent years, but Lviv City Center and major tourist areas have generally been safer than frontline regions. Check official travel advisories and local guidance before planning trips.\n- Currency and payments: Ukrainian hryvnia (UAH). Credit cards widely accepted in urban areas; carry some cash for smaller places.\n- Best time to visit: Spring and autumn for pleasant weather; winter for festive markets and a cozy atmosphere; summer for longer days and lively street life.\n\nIf you’d like, I can tailor this to:\n- A quick 1–2 day Lviv itinerary\n- Specific interests (architecture, food, history, nightlife)\n- Practical travel info (current safety, transport options, or where to stay)'

# %%
ask(
    "In exactly 3 bullet points, describe Lviv's Old Town for a first-time "
    "visitor who has one afternoon. No history lecture — what to actually do.",
    label="1b specific",
)
# Out:
# === 1b specific =================================================
# > In exactly 3 bullet points, describe Lviv's Old Town for a first-time visitor who has one afternoon. No history lecture — what to actually do.
#
# - Start on Rynok Square: grab a coffee and pastry, peek into the Town Hall tower for a quick city view, and people-watch as you map out the rest of the afternoon.
#
# - Stroll the surrounding lanes to the Dominican Church and Armenian Cathedral, wander through their light-filled courtyards, and duck into a cozy café for a quick bite or dessert.
#
# - End at the High Castle viewpoint for sunset over the Old Town, then squeeze in a final bite of local sweets or chocolate before you head out.
#
#   [tokens] prompt=38 thinking=768 answer=114
# '- Start on Rynok Square: grab a coffee and pastry, peek into the Town Hall tower for a quick city view, and people-watch as you map out the rest of the afternoon.\n\n- Stroll the surrounding lanes to the Dominican Church and Armenian Cathedral, wander through their light-filled courtyards, and duck into a cozy café for a quick bite or dessert.\n\n- End at the High Castle viewpoint for sunset over the Old Town, then squeeze in a final bite of local sweets or chocolate before you head out.'

# %% [markdown]
# ### ✍️ Your notes
#
# **What I changed:**
#
# **What changed in the answer:**
#
# **Why I think it changed:**
#
# > The model did not get smarter between those two calls. So what actually changed?

# %% [markdown]
# ---
# ## Experiment 2 — who is it for?
#
# One topic, three audiences. Nothing else differs.

# %%
ask("Explain what an API key is.", label="2a no audience")
# Out:
# === 2a no audience ==============================================
# > Explain what an API key is.
#
# An API key is a simple code (often a long string) that acts as a credential to identify and authenticate an application or user making requests to an API (Application Programming Interface).
#
# Key points:
# - Purpose: The API key tells the service who is requesting data or performing an action, and often what permissions they have.
# - How it’s used: Applications include the key in API requests, usually as a query parameter or an HTTP header (e.g., Authorization or x-api-key). The service checks the key and decides whether to allow the request and what resources/actions are permitted.
# - What it represents: It is not a password for a user; it’s a credential for an application or service. It may be linked to an account or project and can encode scope, quotas, or rate limits.
# - Security considerations:
#   - Do not embed API keys in client-side code exposed to users (e.g., front-end apps); prefer server-side usage or restrictions.
#   - Keep keys secret; if leaked, revoke or rotate immediately.
#   - Use access controls: restrict by IP, referrer, or usage quotas; use scopes to limit what the key can do.
#   - Use additional authentication methods when higher security is needed (e.g., OAuth tokens, short-lived tokens).
# - Lifecycle: Keys can be created, rotated (replaced), scoped, disabled, and revoked. Regular rotation reduces risk.
# - Differences from user passwords: API keys identify the calling application or system, not a human user. They are often long-lived unless rotated.
#
# Simple example:
# - A weather app wants to fetch data from a weather API. It includes an API key in each request to prove it’s authorized to access the data. The API provider checks the key, enforces quotas, and returns the data if allowed. If the key is invalid or over quota, the request is denied.
#
# In short, an API key is a secret token used to authenticate and authorize programmatic access to an API, with security and usage implications tied to how it’s issued, stored, and rotated.
#
#   [tokens] prompt=13 thinking=0 answer=423
# 'An API key is a simple code (often a long string) that acts as a credential to identify and authenticate an application or user making requests to an API (Application Programming Interface).\n\nKey points:\n- Purpose: The API key tells the service who is requesting data or performing an action, and often what permissions they have.\n- How it’s used: Applications include the key in API requests, usually as a query parameter or an HTTP header (e.g., Authorization or x-api-key). The service checks the key and decides whether to allow the request and what resources/actions are permitted.\n- What it represents: It is not a password for a user; it’s a credential for an application or service. It may be linked to an account or project and can encode scope, quotas, or rate limits.\n- Security considerations:\n  - Do not embed API keys in client-side code exposed to users (e.g., front-end apps); prefer server-side usage or restrictions.\n  - Keep keys secret; if leaked, revoke or rotate immediately.\n  - Use access controls: restrict by IP, referrer, or usage quotas; use scopes to limit what the key can do.\n  - Use additional authentication methods when higher security is needed (e.g., OAuth tokens, short-lived tokens).\n- Lifecycle: Keys can be created, rotated (replaced), scoped, disabled, and revoked. Regular rotation reduces risk.\n- Differences from user passwords: API keys identify the calling application or system, not a human user. They are often long-lived unless rotated.\n\nSimple example:\n- A weather app wants to fetch data from a weather API. It includes an API key in each request to prove it’s authorized to access the data. The API provider checks the key, enforces quotas, and returns the data if allowed. If the key is invalid or over quota, the request is denied.\n\nIn short, an API key is a secret token used to authenticate and authorize programmatic access to an API, with security and usage implications tied to how it’s issued, stored, and rotated.'

# %%
ask("Explain what an API key is to a 10-year-old.", label="2b child")
# Out:
# === 2b child ====================================================
# > Explain what an API key is to a 10-year-old.
#
# Imagine you are building a cool Lego castle, but you realize you’re missing a really specific piece—like a tiny dragon.
#
# Your friend has a giant box of Lego dragons at their house. Instead of going all the way to their house, you send a **trained robot messenger** to go get it for you.
#
# But your friend doesn’t just let *any* robot take their toys. They need to make sure it’s *your* robot.
#
# So, you give your robot a **secret code card**. When your robot gets to your friend's house, it shows the card. Your friend checks the card, says, *"Ah, this is from my friend! Here is the dragon,"* and hands it over.
#
# In the computer world:
# * **The robot** is called an **API** (which is just a fancy way of saying a program that fetches information from one place to another).
# * **The secret code card** is the **API Key**.
#
# ### Here is a real-life example:
# Think of a **Weather App** on a phone.
#
# The app doesn't have a giant thermometer sticking out of the top of your phone. Instead, it has a "robot messenger" (an API) that goes to a giant weather computer to ask, *"What is the temperature in New York?"*
#
# But the big weather computer wants to make sure the app is allowed to ask. So, the app shows its **API Key** (its secret code). The weather computer says, *"Yep, your code is good! Here is the temperature."*
#
# ### Why does it need to be secret?
# An API key is like a secret password. If someone else steals your API key, they could use your "robot" to get information, and the big computer might think it's you and charge you money, or block you from using it!
#
# So, an API key is basically a **secret library card for computers** to share information safely!
#
#   [tokens] prompt=17 thinking=819 answer=416
# 'Imagine you are building a cool Lego castle, but you realize you’re missing a really specific piece—like a tiny dragon. \n\nYour friend has a giant box of Lego dragons at their house. Instead of going all the way to their house, you send a **trained robot messenger** to go get it for you. \n\nBut your friend doesn’t just let *any* robot take their toys. They need to make sure it’s *your* robot. \n\nSo, you give your robot a **secret code card**. When your robot gets to your friend\'s house, it shows the card. Your friend checks the card, says, *"Ah, this is from my friend! Here is the dragon,"* and hands it over.\n\nIn the computer world:\n* **The robot** is called an **API** (which is just a fancy way of saying a program that fetches information from one place to another).\n* **The secret code card** is the **API Key**.\n\n### Here is a real-life example:\nThink of a **Weather App** on a phone. \n\nThe app doesn\'t have a giant thermometer sticking out of the top of your phone. Instead, it has a "robot messenger" (an API) that goes to a giant weather computer to ask, *"What is the temperature in New York?"*\n\nBut the big weather computer wants to make sure the app is allowed to ask. So, the app shows its **API Key** (its secret code). The weather computer says, *"Yep, your code is good! Here is the temperature."*\n\n### Why does it need to be secret?\nAn API key is like a secret password. If someone else steals your API key, they could use your "robot" to get information, and the big computer might think it\'s you and charge you money, or block you from using it! \n\nSo, an API key is basically a **secret library card for computers** to share information safely!'

# %%
ask("Explain what an API key is to a security auditor.", label="2c auditor")
# Out:
# === 2c auditor ==================================================
# > Explain what an API key is to a security auditor.
#
# For a security auditor, an **API (Application Programming Interface) key** should be understood not just as a technical mechanism, but as a **high-risk credential** that governs machine-to-machine (M2M) authentication and access control.
#
# Here is a comprehensive breakdown of API keys framed specifically for a security audit, threat modeling, and compliance perspective.
#
# ---
#
# ### 1. Definition and Technical Function
# An API key is a unique, long-lived alphanumeric string used to authenticate a calling program (a client, microservice, or third-party integration) to an API.
#
# From an Identity and Access Management (IAM) perspective:
# * **It acts as a Bearer Token:** Possession of the key is the sole requirement for access. It is typically passed in the HTTP request header (e.g., `Authorization: Bearer <API_KEY>`) or, insecurely, as a query parameter.
# * **It combines Identity and Authentication:** In its simplest form, the key acts as both the username and the password in a single string.
# * **Identification vs. Authorization:** Technically, simple API keys only identify *who* (which project or organization) is calling, not necessarily what they are allowed to do. However, modern systems often associate API keys with specific roles or permissions (scoping).
#
# ---
#
# ### 2. The Auditor’s Threat Model: Risks Associated with API Keys
# Unlike human passwords, which are subject to controls like Multi-Factor Authentication (MFA) and complexity requirements, API keys are static, machine-readable secrets. This introduces specific vulnerabilities:
#
# #### A. Insecure Storage and Exposure (The #1 Risk)
# Because developers need to use these keys in code, they are frequently leaked. Common audit findings include keys:
# * Hardcoded in source code and committed to version control systems (e.g., public GitHub repositories).
# * Stored in plaintext in configuration files or environment files (`.env`).
# * Exposed in client-side code (e.g., mobile apps or frontend JavaScript), where they can be easily extracted by reverse-engineering.
#
# #### B. Lack of Rotation and Lifecycle Management
# API keys are often treated with a "set-and-forget" mentality. Without automated rotation policies, a compromised key can remain active and exploited indefinitely.
#
# #### C. Excessive Privileges (Violation of Least Privilege)
# Many legacy or poorly designed APIs issue "master" keys that grant full read/write/delete access to an entire system, rather than scoped keys restricted to specific endpoints or read-only actions.
#
# #### D. Insufficient Audit Logging (Lack of Non-Repudiation)
# If multiple servers or developers share a single API key, it is impossible to attribute actions to a specific individual or system. In the event of an incident, forensic investigation becomes extremely difficult.
#
# ---
#
# ### 3. API Keys vs. OAuth Tokens (Architectural Distinction)
# As an auditor, you will often need to assess whether an API key is the *appropriate* security control for a given use case:
#
# | Feature | API Key | OAuth 2.0 / OIDC Token |
# | :--- | :--- | :--- |
# | **Lifespan** | Long-lived (often static) | Short-lived (minutes/hours) with refresh tokens |
# | **Primary Use** | Machine-to-Machine (M2M) | User-delegated authorization |
# | **Revocation** | Manual revocation required | Automatic expiration / token revocation list |
# | **Complexity** | Simple to implement | High complexity, requires Authorization Server |
#
# *Auditor's Rule of Thumb:* API keys are acceptable for low-risk, read-only public data or trusted M2M backend communication. They are **not** acceptable for authenticating end-users or handling sensitive transactions (e.g., financial or healthcare data), where OAuth 2.0 should be mandated.
#
# ---
#
# ### 4. What to Look for During an Audit (Audit Checklist)
# When auditing an organization’s use of API keys, you should verify the following controls:
#
# * **Secret Management:** Are keys stored in a dedicated Secrets Manager (e.g., HashiCorp Vault, AWS Secrets Manager, Azure Key Vault) rather than configuration files or code?
# * **Scanning Tools:** Is the organization using static application security testing (SAST) or secret-scanning tools (e.g., GitGuardian, TruffleHog) in their CI/CD pipeline to detect leaked keys?
# * **Transmission Security:** Are keys strictly transmitted over HTTPS? Are they passed in the HTTP Headers, and *never* in the URL query string (which gets logged in web server history)?
# * **IP and Domain Restrictions:** Are the keys restricted to specific source IP addresses or referrer URLs to minimize the blast radius of a leak?
# * **Least Privilege (Scoping):** Are the keys restricted to the minimum required API endpoints and actions (e.g., read-only)?
# * **Rotation Policy:** Is there a documented and tested process for rotating API keys periodically, and an emergency revocation procedure for compromised keys?
#
#   [tokens] prompt=12 thinking=933 answer=1066
# 'For a security auditor, an **API (Application Programming Interface) key** should be understood not just as a technical mechanism, but as a **high-risk credential** that governs machine-to-machine (M2M) authentication and access control. \n\nHere is a comprehensive breakdown of API keys framed specifically for a security audit, threat modeling, and compliance perspective.\n\n---\n\n### 1. Definition and Technical Function\nAn API key is a unique, long-lived alphanumeric string used to authenticate a calling program (a client, microservice, or third-party integration) to an API. \n\nFrom an Identity and Access Management (IAM) perspective:\n* **It acts as a Bearer Token:** Possession of the key is the sole requirement for access. It is typically passed in the HTTP request header (e.g., `Authorization: Bearer <API_KEY>`) or, insecurely, as a query parameter.\n* **It combines Identity and Authentication:** In its simplest form, the key acts as both the username and the password in a single string.\n* **Identification vs. Authorization:** Technically, simple API keys only identify *who* (which project or organization) is calling, not necessarily what they are allowed to do. However, modern systems often associate API keys with specific roles or permissions (scoping).\n\n---\n\n### 2. The Auditor’s Threat Model: Risks Associated with API Keys\nUnlike human passwords, which are subject to controls like Multi-Factor Authentication (MFA) and complexity requirements, API keys are static, machine-readable secrets. This introduces specific vulnerabilities:\n\n#### A. Insecure Storage and Exposure (The #1 Risk)\nBecause developers need to use these keys in code, they are frequently leaked. Common audit findings include keys:\n* Hardcoded in source code and committed to version control systems (e.g., public GitHub repositories).\n* Stored in plaintext in configuration files or environment files (`.env`).\n* Exposed in client-side code (e.g., mobile apps or frontend JavaScript), where they can be easily extracted by reverse-engineering.\n\n#### B. Lack of Rotation and Lifecycle Management\nAPI keys are often treated with a "set-and-forget" mentality. Without automated rotation policies, a compromised key can remain active and exploited indefinitely.\n\n#### C. Excessive Privileges (Violation of Least Privilege)\nMany legacy or poorly designed APIs issue "master" keys that grant full read/write/delete access to an entire system, rather than scoped keys restricted to specific endpoints or read-only actions.\n\n#### D. Insufficient Audit Logging (Lack of Non-Repudiation)\nIf multiple servers or developers share a single API key, it is impossible to attribute actions to a specific individual or system. In the event of an incident, forensic investigation becomes extremely difficult.\n\n---\n\n### 3. API Keys vs. OAuth Tokens (Architectural Distinction)\nAs an auditor, you will often need to assess whether an API key is the *appropriate* security control for a given use case:\n\n| Feature | API Key | OAuth 2.0 / OIDC Token |\n| :--- | :--- | :--- |\n| **Lifespan** | Long-lived (often static) | Short-lived (minutes/hours) with refresh tokens |\n| **Primary Use** | Machine-to-Machine (M2M) | User-delegated authorization |\n| **Revocation** | Manual revocation required | Automatic expiration / token revocation list |\n| **Complexity** | Simple to implement | High complexity, requires Authorization Server |\n\n*Auditor\'s Rule of Thumb:* API keys are acceptable for low-risk, read-only public data or trusted M2M backend communication. They are **not** acceptable for authenticating end-users or handling sensitive transactions (e.g., financial or healthcare data), where OAuth 2.0 should be mandated.\n\n---\n\n### 4. What to Look for During an Audit (Audit Checklist)\nWhen auditing an organization’s use of API keys, you should verify the following controls:\n\n* **Secret Management:** Are keys stored in a dedicated Secrets Manager (e.g., HashiCorp Vault ...

# %% [markdown]
# ### ✍️ Your notes
#
# **What I changed:**
#
# **What changed in the answer:**
#
# **Why I think it changed:**
#
# > With no audience given, the model did not refuse and did not ask. It picked one.
# > What else might it be quietly picking for you?

# %% [markdown]
# ---
# ## Experiment 3 — ask for a shape
#
# Ask for a strict output format, then check whether you actually got it.

# %%
answer = ask(
    "List 3 risks of committing an API key to a public repository. "
    "Return ONLY a JSON array of objects with keys 'risk' and 'severity'. ",
    label="3 format constraint",
)
# Out:
# === 3 format constraint =========================================
# > List 3 risks of committing an API key to a public repository. Return ONLY a JSON array of objects with keys 'risk' and 'severity'.
#
# [
#   {
#     "risk": "Financial theft through unauthorized consumption of paid API resources or cloud services.",
#     "severity": "High"
#   },
#   {
#     "risk": "Unauthorized access to sensitive database records, customer data, or proprietary infrastructure.",
#     "severity": "Critical"
#   },
#   {
#     "risk": "Immediate service disruption and application downtime resulting from the API provider automatically revoking the exposed key.",
#     "severity": "Medium"
#   }
# ]
#
#   [tokens] prompt=32 thinking=669 answer=108

# %%
# Did it really return parseable JSON? Find out rather than assume.
import json

try:
    parsed = json.loads(answer)
    print("Parsed cleanly:", parsed)
except json.JSONDecodeError as exc:
    print("NOT valid JSON:", exc)
    print("\nWhat we actually got back:\n")
    print(repr(answer[:300]))
# Out:
# Parsed cleanly: [{'risk': 'Financial theft through unauthorized consumption of paid API resources or cloud services.', 'severity': 'High'}, {'risk': 'Unauthorized access to sensitive database records, customer data, or proprietary infrastructure.', 'severity': 'Critical'}, {'risk': 'Immediate service disruption and application downtime resulting from the API provider automatically revoking the exposed key.', 'severity': 'Medium'}]

# %% [markdown]
# ---
# ## Experiment 4 — something it cannot know
#
# This is the important one.
#
# First ask about something absent from the model's training data. Then paste the source
# in and ask exactly the same question again.

# %%
ask(
    "What is assessed in Lab 2 of the Modern AI Systems course, "
    "and what is it worth?",
    label="4a no context",
)
# Out:
# === 4a no context ===============================================
# > What is assessed in Lab 2 of the Modern AI Systems course, and what is it worth?
#
# Because **"Modern AI Systems"** (or "Modern Machine Learning Systems") is a course title used by several different universities and online platforms, the exact details of Lab 2—both its content and its grading weight—depend entirely on the specific institution or program you are referring to.
#
# To give you the exact answer, **please reply with the name of the university, online platform, or course code** (for example, Stanford, CMU, Northeastern, etc.).
#
# In the meantime, here is what is typically assessed in "Lab 2" of common AI/ML Systems courses, along with standard grading weights:
#
# ### 1. Typical Content Assessed in AI Systems Lab 2
# If the course focuses on the **systems side** of AI (engineering, deployment, and infrastructure), Lab 2 usually moves past basic environment setup and focuses on:
# *   **Model Deployment & APIs:** Packaging a trained model (like a transformer or CNN) into a REST API using frameworks like FastAPI or Flask.
# *   **Containerization:** Writing Dockerfiles to containerize the ML application to ensure reproducibility across different environments.
# *   **Inference Optimization:** Benchmarking and optimizing model inference latency using tools like ONNX, TensorRT, or quantization techniques.
# *   **Data Pipelines:** Setting up basic data ingestion or preprocessing pipelines (using tools like DVC or Apache Airflow).
#
# ### 2. What It is Typically Worth
# *   In most university computer science or data science courses, individual lab assignments are worth between **5% to 15% of the final course grade**.
# *   If the course has a heavy lab component (e.g., 4 or 5 major labs making up the bulk of the grade), Lab 2 is often worth **10% to 20%** of the total grade.
#
# **If you can specify which university or platform's course you are taking, I can provide the exact syllabus details for Lab 2!**
#
#   [tokens] prompt=21 thinking=1161 answer=411
# 'Because **"Modern AI Systems"** (or "Modern Machine Learning Systems") is a course title used by several different universities and online platforms, the exact details of Lab 2—both its content and its grading weight—depend entirely on the specific institution or program you are referring to. \n\nTo give you the exact answer, **please reply with the name of the university, online platform, or course code** (for example, Stanford, CMU, Northeastern, etc.).\n\nIn the meantime, here is what is typically assessed in "Lab 2" of common AI/ML Systems courses, along with standard grading weights:\n\n### 1. Typical Content Assessed in AI Systems Lab 2\nIf the course focuses on the **systems side** of AI (engineering, deployment, and infrastructure), Lab 2 usually moves past basic environment setup and focuses on:\n*   **Model Deployment & APIs:** Packaging a trained model (like a transformer or CNN) into a REST API using frameworks like FastAPI or Flask.\n*   **Containerization:** Writing Dockerfiles to containerize the ML application to ensure reproducibility across different environments.\n*   **Inference Optimization:** Benchmarking and optimizing model inference latency using tools like ONNX, TensorRT, or quantization techniques.\n*   **Data Pipelines:** Setting up basic data ingestion or preprocessing pipelines (using tools like DVC or Apache Airflow).\n\n### 2. What It is Typically Worth\n*   In most university computer science or data science courses, individual lab assignments are worth between **5% to 15% of the final course grade**. \n*   If the course has a heavy lab component (e.g., 4 or 5 major labs making up the bulk of the grade), Lab 2 is often worth **10% to 20%** of the total grade.\n\n**If you can specify which university or platform\'s course you are taking, I can provide the exact syllabus details for Lab 2!**'

# %% [markdown]
# Now paste a few lines from the course syllabus into `source_text` below —
# the Lab 2 block from Week 7 is the one to use.

# %%
source_text = """
| Deliverable                         | Due     | Points |
| ----------------------------------- | ------- | -----: |
| Lab 1 — Vector RAG                  | Week 4  |     20 |
| Lab 2 — Knowledge graph / Graph RAG | Week 7  |     25 |
| Lab 3 — Agent, tools, memory        | Week 10 |     35 |
| Final integrated project            | Week 12 |     20 |
"""

ask(
    "Using ONLY the text below, answer: what is assessed in Lab 2 of the "
    "Modern AI Systems course, and what is it worth? "
    "If the text does not say, reply exactly: not stated.\n\n" + source_text,
    label="4b with context",
)
# Out:
# === 4b with context =============================================
# > Using ONLY the text below, answer: what is assessed in Lab 2 of the Modern AI Systems course, and what is it worth? If the text does not say, reply exactly: not stated.
#
#
# | Deliverable
#
# Based on the provided text, Lab 2 assesses **Knowledge graph / Graph RAG** and is worth **25 points**.
#
#   [tokens] prompt=146 thinking=339 answer=26
# 'Based on the provided text, Lab 2 assesses **Knowledge graph / Graph RAG** and is worth **25 points**.'

# %% [markdown]
# ### ✍️ Your notes
#
# **What I changed:**
#
# **What changed in the answer:**
#
# **Why I think it changed:**
#
# > The model learned nothing between those two calls. Only what it could see changed.
# >
# > Notice the instruction to reply *"not stated"*. Why does that matter, and what would
# > happen without it?

# %% [markdown]
# ---
# ## Experiment 5 — the same prompt, three times
#
# Identical input. Three times.

# %%
repeat("Name one interesting fact about graph databases.", n=3,
       label="5 same prompt, three times")
# Out:
# === 5 same prompt, three times ==================================
#
# --- run 1 of 3 ---
# > Name one interesting fact about graph databases.
#
# One of the most interesting facts about graph databases is that **their query speed remains virtually constant even as the database grows to billions of records.**
#
# In traditional relational databases (like SQL), finding connections between data requires using "JOIN" operations, which search through massive indexes to link tables together. As the database grows, these searches get exponentially slower.
#
# Graph databases solve this using a concept called **index-free adjacency**. Instead of searching an index, every data point (node) stores a direct physical pointer to its neighbors on the hard drive or in memory. Because the database simply "walks" along these pre-established connections, finding a "friend of a friend of a friend" takes milliseconds, whether the database contains 10,000 records or 10 billion.
#
#   [tokens] prompt=9 thinking=680 answer=161
#
# --- run 2 of 3 ---
# > Name one interesting fact about graph databases.
#
# One of the most interesting facts about graph databases is that **their query speed remains constant even as the size of the database grows to billions of records.**
#
# Unlike traditional relational databases (SQL), which slow down as they grow because they have to search through massive index tables to join data, graph databases use a principle called **"index-free adjacency."**
#
# This means every data point (node) physically stores direct pointers to its neighboring data points. When querying, the database simply hops from pointer to pointer. As a result, finding a connection across a database of 10 billion records takes the exact same amount of time as doing it in a database of 10 thousand records.
#
#   [tokens] prompt=9 thinking=519 answer=140
#
# --- run 3 of 3 ---
# > Name one interesting fact about graph databases.
#
# One of the most interesting facts about graph databases is that they use a property called **"index-free adjacency."**
#
# In traditional relational (SQL) databases, finding connections between data requires searching through massive index tables (using costly "JOIN" operations), which slows down drastically as the database grows. In contrast, a graph database stores relationships as direct physical pointers on the hard drive.
#
# This means traversing millions of connections takes milliseconds, and **query speed remains lightning-fast regardless of how large the overall database becomes.**
#
#   [tokens] prompt=9 thinking=497 answer=106
#
#   [all 3 runs identical? False]
# ['One of the most interesting facts about graph databases is that **their query speed remains virtually constant even as the database grows to billions of records.** \n\nIn traditional relational databases (like SQL), finding connections between data requires using "JOIN" operations, which search through massive indexes to link tables together. As the database grows, these searches get exponentially slower. \n\nGraph databases solve this using a concept called **index-free adjacency**. Instead of searching an index, every data point (node) stores a direct physical pointer to its neighbors on the hard drive or in memory. Because the database simply "walks" along these pre-established connections, finding a "friend of a friend of a friend" takes milliseconds, whether the database contains 10,000 records or 10 billion.',
#  'One of the most interesting facts about graph databases is that **their query speed remains constant even as the size of the database grows to billions of records.** \n\nUnlike traditional relational databases (SQL), which slow down as they grow because they have to search through massive index tables to join data, graph databases use a principle called **"index-free adjacency."** \n\nThis means every data point (node) physically stores direct pointers to its neighboring data points. When querying, the database simply hops from pointer to pointer. As a result, finding a connection across a database of 10 billion records takes the exact same amount of time as doing it in a database of 10 thousand records.',
#  'One of the most interesting facts about graph databases is that they use a property called **"index-free adjacency."** \n\nIn traditional relational (SQL) databases, finding connections between data requires searching through massive index tables (using costly "JOIN" operations), which slows down drastically as the database grows. In contrast, a graph database stores relationships as direct physical pointers on the hard drive. \n\nThis means traversing millions of connections takes milliseconds, and **query speed remains lightning-fast regardless of how large the overall database becomes.**']

# %% [markdown]
# ### ✍️ Your notes
#
# **What I changed:**
#
# **What changed in the answer:**
#
# **Why I think it changed:**
#
# > Look at the token counts as well as the answers.
# >
# > How do you write a test for something that does not return the same thing twice?

# %% [markdown]
# ---
# ## Before you close this
#
# Read back your five notes cells, then answer in one sentence:
#
# **What did you actually change across all five experiments?**
#
# *(Not the model. Not what it knows.)*
